# %%
# !pip install deeplabcut
# !pip install --upgrade "tensorflow<=2.10"

# %%
import deeplabcut
import os

# %%
# Check if the file exists
config_path = '/content/drive/My Drive/Research/YellowHeadCroppedVid1-Adam-2024-05-29/config.yaml'

deeplabcut.train_network(config_path)
